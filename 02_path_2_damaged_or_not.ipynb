# %% [markdown]
# Importing all the required libraries for this project

# %%
import os
import h5py
import numpy as np
import json
import urllib.request
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from IPython.display import Image, display, clear_output
from sklearn.metrics import classification_report, confusion_matrix
import kagglehub
# %matplotlib inline
sns.set_style('whitegrid')

# %%
from keras import optimizers
from keras.applications.vgg16 import VGG16
from keras.models import Sequential, load_model, Model
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D, Activation, Dropout, Flatten, Dense, Input
from keras.regularizers import l2, l1
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.callbacks import ModelCheckpoint, History
from keras import backend as K
from tensorflow.keras.utils import get_file

# %% [markdown]
# # Using TensorFlow backend.

# %% [markdown]
# This code defines a function called plot_metrics that is designed to visualize the performance of a machine learning model during training. It takes two arguments:
#
# hist: This is expected to be a dictionary-like object (likely a Keras History object) containing training metrics such as accuracy and loss for both the training and validation sets. These metrics are recorded during the model's training process. stop: This argument controls the number of epochs (iterations of training) to display on the plots. It defaults to 50

# %%
def plot_metrics(hist, stop=50):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,4))

    axes = axes.flatten()

    axes[0].plot(range(stop), hist['acc'], label='Training', color='#FF533D')
    axes[0].plot(range(stop), hist['val_acc'], label='Validation', color='#03507E')
    axes[0].set_title('Accuracy')
    axes[0].set_ylabel('Accuracy')
    axes[0].set_xlabel('Epoch')
    axes[0].legend(loc='lower right')

    axes[1].plot(range(stop), hist['loss'], label='Training', color='#FF533D')
    axes[1].plot(range(stop), hist['val_loss'], label='Validation', color='#03507E')
    axes[1].set_title('Loss')
    axes[1].set_ylabel('Loss')
    axes[1].set_xlabel('Epoch')
    axes[1].legend(loc='upper right')

    plt.tight_layout();

    print("Best Model:")
    print_best_model_results(hist)

# %% [markdown]
# This code defines a function called plot_acc_metrics. This function's primary purpose is to create a plot that visually compares the accuracy of a machine learning model during two phases: initial training and fine-tuning

# %%
def plot_acc_metrics(hist1, hist2, stop=50):
    fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(4.25,6))

    axes = axes.flatten()

    axes[0].plot(range(stop), hist1['acc'], label='Training', color='#FF533D')
    axes[0].plot(range(stop), hist1['val_acc'], label='Validation', color='#03507E')
    axes[0].set_title('Training')
    axes[0].set_ylabel('Accuracy')
    axes[0].set_xlabel('Epoch')
    axes[0].legend(loc='lower right')

    axes[1].plot(range(stop), hist2['acc'], label='Training', color='#FF533D')
    axes[1].plot(range(stop), hist2['val_acc'], label='Validation', color='#03507E')
    axes[1].set_title('Fine-tuning')
    axes[1].set_ylabel('Accuracy')
    axes[1].set_xlabel('Epoch')
    axes[1].legend(loc='lower right')

    plt.tight_layout();

# %% [markdown]
# This function, print_best_model_results, is designed to identify and display the best performing epoch of a machine learning model based on its validation accuracy.

# %%
def print_best_model_results(model_hist):
    best_epoch = np.argmax(model_hist['val_acc'])
    print('epoch:', best_epoch+1, \
    ', val_acc:', model_hist['val_acc'][best_epoch], \
    ', val_loss:', model_hist['val_loss'][best_epoch])

# %% [markdown]
# This function, save_bottleneck_features, is designed to extract and save features from images using a pre-trained neural network called VGG16. These extracted features are often referred to as "bottleneck features.

# %%
def save_bottleneck_features():
    datagen = ImageDataGenerator(rescale=1./255)

    model = VGG16(include_top=False, weights='imagenet')

    generator = datagen.flow_from_directory(train_data_dir, target_size=(img_width, img_height), batch_size=batch_size, class_mode=None, shuffle=False)
    bottleneck_features_train = model.predict_generator(generator, nb_train_samples // batch_size)
    np.save(location+'/bottleneck_features_train.npy', bottleneck_features_train)

    generator = datagen.flow_from_directory(validation_data_dir, target_size=(img_width, img_height), batch_size=batch_size, class_mode=None, shuffle=False)
    bottleneck_features_validation = model.predict_generator(generator, nb_validation_samples // batch_size)
    np.save(location+'/bottleneck_features_validation.npy', bottleneck_features_validation)

# %% [markdown]
# This function is the core of training a machine learning model, specifically what's often referred to as "transfer learning." It leverages pre-trained models (like VGG16) to speed up and improve the training process.

# %%
def train_top_model():
    train_data = np.load(location+'/bottleneck_features_train.npy')
    train_labels = np.array([0] * (nb_train_samples // 2) + [1] * (nb_train_samples // 2))

    validation_data = np.load(location+'/bottleneck_features_validation.npy')
    validation_labels = np.array([0] * (nb_validation_samples // 2) + [1] * (nb_validation_samples // 2))

    model = Sequential()
    model.add(Flatten(input_shape=train_data.shape[1:]))
    model.add(Dense(256,activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1,activation='sigmoid'))
    model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

    checkpoint = ModelCheckpoint(top_model_weights_path, monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=True, mode='auto')

    fit = model.fit(train_data, train_labels, epochs=epochs, batch_size=batch_size,validation_data=(validation_data,validation_labels), callbacks=[checkpoint])

    with open(location+'/top_history.txt', 'w') as f:
        json.dump(fit.history, f)

    return model, fit.history

# %% [markdown]
# This function is designed to fine-tune a pre-trained VGG16 model for a binary image classification task

# %%
def finetune_binary_model():
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=(256,256,3))
    print("Model loaded.")

    top_model = Sequential()
    top_model.add(Flatten(input_shape=base_model.output_shape[1:]))
    top_model.add(Dense(256, activation='relu'))
    top_model.add(Dropout(0.5))
    top_model.add(Dense(1, activation='sigmoid'))

    top_model.load_weights(top_model_weights_path)

    model = Model(inputs=base_model.input, outputs=top_model(base_model.output))

    for layer in model.layers[:25]:
        layer.trainable = False

    model.compile(loss='binary_crossentropy', optimizer=optimizers.SGD(lr=1e-4, momentum=0.9), metrics=['accuracy'])

    train_datagen = ImageDataGenerator(rescale = 1./255, zoom_range=0.2, shear_range=0.2, horizontal_flip=True)

    test_datagen = ImageDataGenerator(rescale=1./255)

    train_generator = train_datagen.flow_from_directory(train_data_dir, target_size=(img_height, img_width), batch_size=batch_size, class_mode='binary')

    validation_generator = test_datagen.flow_from_directory(validation_data_dir, target_size=(img_height, img_width), batch_size=batch_size, class_mode='binary')

    checkpoint = ModelCheckpoint(fine_tuned_model_path, monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto')

    fit = model.fit_generator(train_generator, steps_per_epoch=nb_train_samples//batch_size, epochs=epochs, validation_data=validation_generator, validation_steps=nb_validation_samples//batch_size, verbose=1, callbacks=[checkpoint])

    with open(location+'/ft_history.txt', 'w') as f:
        json.dump(fit.history, f)

    return model, fit.history

# %% [markdown]
# This function is designed to evaluate the performance of a trained binary classification model, specifically one used for image classification. It takes three arguments:
#
# model: This is the trained machine learning model you want to evaluate. directory: This is the path to the directory containing the images you want to use for evaluation. labels: These are the true labels (0 or 1) for the images in the directory.

# %%
def evaluate_binary_model(model, directory, labels):
    datagen = ImageDataGenerator(rescale=1./255)

    generator = datagen.flow_from_directory(directory, target_size=(img_height,img_width), batch_size=batch_size, class_mode='binary', shuffle=False)

    predictions = model.predict_generator(generator, len(labels))

    pred_labels = [0 if i<0.5 else 1 for i in predictions]

    print('')
    print(classification_report(validation_labels, pred_labels))
    print('')
    cm = confusion_matrix(validation_labels, pred_labels)
    return cm

# %% [markdown]
# # Defining input data

# %% [markdown]
# This code snippet is primarily focused on defining important variables that will be used throughout the machine learning project. These variables specify where data is located, where to store model files, and settings for the training process.

# %%
location = '/content/drive/MyDrive/data2'
top_model_weights_path = location+'/top_model_weights.h5'
fine_tuned_model_path = location+'/ft_model.h5'

train_data_dir = location+'/training'
validation_data_dir = location+'/validation'
train_samples = [len(os.listdir(train_data_dir+'/'+i)) for i in sorted(os.listdir(train_data_dir))]
nb_train_samples = 1824
validation_samples = [len(os.listdir(validation_data_dir+'/'+i)) for i in sorted(os.listdir(validation_data_dir))]
nb_validation_samples = 448

img_width, img_height = 256,256
epochs = 50
batch_size = 16

# %% [markdown]
# This is responsible for initiating the feature extraction process using a pre-trained model called VGG16. This process is a crucial step in transfer learning, which leverages a model trained on a large dataset (ImageNet in this case) to improve the performance of our specific task.

# %%
def save_bottleneck_features():
    datagen = ImageDataGenerator(rescale=1./255)

    model = VGG16(include_top=False, weights='imagenet')

    generator = datagen.flow_from_directory(train_data_dir, target_size=(img_width, img_height), batch_size=batch_size, class_mode=None, shuffle=False)
    # Use predict instead of predict_generator
    bottleneck_features_train = model.predict(generator, steps=nb_train_samples // batch_size)
    np.save(location+'/bottleneck_features_train.npy', bottleneck_features_train)

    generator = datagen.flow_from_directory(validation_data_dir, target_size=(img_width, img_height), batch_size=batch_size, class_mode=None, shuffle=False)
    # Use predict instead of predict_generator
    bottleneck_features_validation = model.predict(generator, steps=nb_validation_samples // batch_size)
    np.save(location+'/bottleneck_features_validation.npy', bottleneck_features_validation)

# %% [markdown]
# These two lines of code together perform the core steps of transfer learning:
#
# Extract features from images using a pre-trained model (save_bottleneck_features()). Train a new classification model on top of these extracted features (train_top_model()). This approach can significantly reduce training time and improve performance compared to training a model from scratch.

# %%
# Call the function to actually create and save bottleneck features:
save_bottleneck_features()
# Out:
# Found 1840 images belonging to 2 classes.
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 14s 97ms/step
# Found 460 images belonging to 2 classes.
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step

# %% [markdown]
# This line of code is defining a variable called top_model_weights_path. This variable is crucial because it stores the file path where the trained weights of your "top model" will be saved.

# %%
top_model_weights_path = location+'/top_model_weights.weights.h5' # Changed .h5 to .weights.h5

# %% [markdown]
#  This single line of code initiates the process of training a classification model using transfer learning. It relies on a previously defined function (train_top_model) to do the heavy lifting and then stores the resulting trained model and its training history in variables for later use.

# %%
d2_model1, d2_history1 = train_top_model()
# Out:
# Epoch 1/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7027 - loss: 3.1783 - val_accuracy: 0.6518 - val_loss: 0.9900
# Epoch 2/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8316 - loss: 0.4425 - val_accuracy: 0.8795 - val_loss: 0.3743
# Epoch 3/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8752 - loss: 0.3759 - val_accuracy: 0.8862 - val_loss: 0.2748
# Epoch 4/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8660 - loss: 0.3231 - val_accuracy: 0.9062 - val_loss: 0.3169
# Epoch 5/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9003 - loss: 0.2917 - val_accuracy: 0.9219 - val_loss: 0.2292
# Epoch 6/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9070 - loss: 0.2860 - val_accuracy: 0.9040 - val_loss: 0.2783
# Epoch 7/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9226 - loss: 0.1811 - val_accuracy: 0.9062 - val_loss: 0.3210
# Epoch 8/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9380 - loss: 0.1920 - val_accuracy: 0.9152 - val_loss: 0.2626
# Epoch 9/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9453 - loss: 0.1381 - val_accuracy: 0.8795 - val_loss: 0.4015
# Epoch 10/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9550 - loss: 0.1186 - val_accuracy: 0.8728 - val_loss: 0.4376
# Epoch 11/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9638 - loss: 0.0977 - val_accuracy: 0.9196 - val_loss: 0.3033
# Epoch 12/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9698 - loss: 0.0783 - val_accuracy: 0.8951 - val_loss: 0.6816
# Epoch 13/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9660 - loss: 0.0845 - val_accuracy: 0.9129 - val_loss: 0.3740
# Epoch 14/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9731 - loss: 0.0753 - val_accuracy: 0.9219 - val_loss: 0.3688
# Epoch 15/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9823 - loss: 0.0667 - val_accuracy: 0.9107 - val_loss: 0.4191
# Epoch 16/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9746 - loss: 0.0633 - val_accuracy: 0.9018 - val_loss: 0.4548
# Epoch 17/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9809 - loss: 0.0585 - val_accuracy: 0.9107 - val_loss: 0.4950
# Epoch 18/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9791 - loss: 0.0507 - val_accuracy: 0.9174 - val_loss: 0.4960
# Epoch 19/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9676 - loss: 0.0876 - val_accuracy: 0.8884 - val_loss: 0.3787
# Epoch 20/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9924 - loss: 0.0341 - val_accuracy: 0.9062 - val_loss: 0.4088
# Epoch 21/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9890 - loss: 0.0364 - val_accuracy: 0.9196 - val_loss: 0.5428
# Epoch 22/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9866 - loss: 0.0411 - val_accuracy: 0.9219 - val_loss: 0.5586
# Epoch 23/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9844 - loss: 0.0494 - val_accuracy: 0.9107 - val_loss: 0.5460
# Epoch 24/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9868 - loss: 0.0457 - val_accuracy: 0.9085 - val_loss: 0.6498
# Epoch 25/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9861 - loss: 0.0395 - val_accuracy: 0.9107 - val_loss: 0.4912
# Epoch 26/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9928 - loss: 0.0218 - val_accuracy: 0.9129 - val_loss: 0.8159
# Epoch 27/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9868 - loss: 0.0438 - val_accuracy: 0.9040 - val_loss: 0.8337
# Epoch 28/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9858 - loss: 0.0360 - val_accuracy: 0.9129 - val_loss: 0.5651
# Epoch 29/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9941 - loss: 0.0197 - val_accuracy: 0.9219 - val_loss: 0.5582
# Epoch 30/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9937 - loss: 0.0198 - val_accuracy: 0.9241 - val_loss: 0.7868
# Epoch 31/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9881 - loss: 0.0401 - val_accuracy: 0.9152 - val_loss: 0.6117
# Epoch 32/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9964 - loss: 0.0167 - val_accuracy: 0.8951 - val_loss: 0.8006
# Epoch 33/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9904 - loss: 0.0206 - val_accuracy: 0.9196 - val_loss: 0.7234
# Epoch 34/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9909 - loss: 0.0280 - val_accuracy: 0.9152 - val_loss: 0.5264
# Epoch 35/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9922 - loss: 0.0257 - val_accuracy: 0.9107 - val_loss: 0.8844
# Epoch 36/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9955 - loss: 0.0189 - val_accuracy: 0.8973 - val_loss: 1.0652
# Epoch 37/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9866 - loss: 0.0290 - val_accuracy: 0.9107 - val_loss: 0.8227
# Epoch 38/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9966 - loss: 0.0087 - val_accuracy: 0.9129 - val_loss: 0.7297
# Epoch 39/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9936 - loss: 0.0140 - val_accuracy: 0.9152 - val_loss: 0.8501
# Epoch 40/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9965 - loss: 0.0197 - val_accuracy: 0.8862 - val_loss: 0.9944
# Epoch 41/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9982 - loss: 0.0133 - val_accuracy: 0.9040 - val_loss: 0.8119
# Epoch 42/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9914 - loss: 0.0199 - val_accuracy: 0.9174 - val_loss: 0.9026
# Epoch 43/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9949 - loss: 0.0110 - val_accuracy: 0.9152 - val_loss: 0.7761
# Epoch 44/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9931 - loss: 0.0138 - val_accuracy: 0.9152 - val_loss: 0.8815
# Epoch 45/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9968 - loss: 0.0121 - val_accuracy: 0.9062 - val_loss: 0.9920
# Epoch 46/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9928 - loss: 0.0222 - val_accuracy: 0.9129 - val_loss: 1.0415
# Epoch 47/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9906 - loss: 0.0429 - val_accuracy: 0.9107 - val_loss: 0.9408
# Epoch 48/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9964 - loss: 0.0112 - val_accuracy: 0.9085 - val_loss: 1.1028
# Epoch 49/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9907 - loss: 0.0384 - val_accuracy: 0.9219 - val_loss: 1.0182
# Epoch 50/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9946 - loss: 0.0291 - val_accuracy: 0.9085 - val_loss: 0.9777

# %% [markdown]
# The main purpose of this function, plot_metrics, is to create a visual representation of a machine learning model's performance during its training process. It generates two plots side-by-side: one for accuracy and one for loss. This helps in understanding how well the model is learning and generalizing to new data.

# %%
def plot_metrics(hist, stop=50):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,4))

    axes = axes.flatten()

    # Replace 'acc' with 'accuracy' and 'val_acc' with 'val_accuracy'
    axes[0].plot(range(stop), hist['accuracy'], label='Training', color='#FF533D')
    axes[0].plot(range(stop), hist['val_accuracy'], label='Validation', color='#03507E')
    axes[0].set_title('Accuracy')
    axes[0].set_ylabel('Accuracy')
    axes[0].set_xlabel('Epoch')
    axes[0].legend(loc='lower right')

    # Replace 'loss' with whatever key your history uses for training loss
    # and 'val_loss' with the key for validation loss
    axes[1].plot(range(stop), hist['loss'], label='Training', color='#FF533D')
    axes[1].plot(range(stop), hist['val_loss'], label='Validation', color='#03507E')
    axes[1].set_title('Loss')
    axes[1].set_ylabel('Loss')
    axes[1].set_xlabel('Epoch')
    axes[1].legend(loc='upper right')

    plt.tight_layout();

    print("Best Model:")
    print_best_model_results(hist) # You might need to adjust print_best_model_results as well

# %% [markdown]
# This line of code is calling the function plot_metrics that was defined earlier in the notebook. It's passing d2_history1 as an argument to this function.

# %%
plot_metrics(d2_history1)
# Out:
# Best Model:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-439c20499a42> in <cell line: 1>()
# ----> 1 plot_metrics(d2_history1)
#
# <ipython-input-27-0ad8926feff8> in plot_metrics(hist, stop)
#      24
#      25     print("Best Model:")
# ---> 26     print_best_model_results(hist) # You might need to adjust print_best_model_results as well
#
# <ipython-input-9-2e54ec266443> in print_best_model_results(model_hist)
#       1 def print_best_model_results(model_hist):
# ----> 2     best_epoch = np.argmax(model_hist['val_acc'])
#       3     print('epoch:', best_epoch+1, \
#       4     ', val_acc:', model_hist['val_acc'][best_epoch], \
#       5     ', val_loss:', model_hist['val_loss'][best_epoch])
#
# KeyError: 'val_acc'

# %% [markdown]
# # Fine Tuning

# %% [markdown]
# These three lines perform the following:
#
# Extract features: Pre-process image data to get important information for training.
#
# Set weights path: Specify where to save the trained model's parameters.
#
# Train the model: Use extracted features to train a classification model, leveraging transfer learning from a pre-trained model (VGG16).

# %%
save_bottleneck_features() #Extract features

# Cell 3
top_model_weights_path = location+'/top_model_weights.weights.h5' # Changed .h5 to .weights.h5

# Cell 4
d2_model1, d2_history1 = train_top_model() # Now train_top_model uses the correct path
# Out:
# Found 1840 images belonging to 2 classes.
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 12s 98ms/step
# Found 460 images belonging to 2 classes.
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6850 - loss: 2.7534 - val_accuracy: 0.8929 - val_loss: 0.2689
# Epoch 2/50
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks/model_checkpoint.py:206: UserWarning: Can save best model only with val_acc available, skipping.
#   self._save_model(epoch=epoch, batch=None, logs=logs)
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8225 - loss: 0.4361 - val_accuracy: 0.8951 - val_loss: 0.2523
# Epoch 3/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8551 - loss: 0.3440 - val_accuracy: 0.8973 - val_loss: 0.2864
# Epoch 4/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8868 - loss: 0.2961 - val_accuracy: 0.8996 - val_loss: 0.2674
# Epoch 5/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8879 - loss: 0.2742 - val_accuracy: 0.9174 - val_loss: 0.2627
# Epoch 6/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9067 - loss: 0.2654 - val_accuracy: 0.9062 - val_loss: 0.2746
# Epoch 7/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9160 - loss: 0.2037 - val_accuracy: 0.7656 - val_loss: 0.9205
# Epoch 8/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9114 - loss: 0.2416 - val_accuracy: 0.9219 - val_loss: 0.2530
# Epoch 9/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9390 - loss: 0.1686 - val_accuracy: 0.9040 - val_loss: 0.3102
# Epoch 10/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9539 - loss: 0.1136 - val_accuracy: 0.9241 - val_loss: 0.2712
# Epoch 11/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9625 - loss: 0.1004 - val_accuracy: 0.9040 - val_loss: 0.3644
# Epoch 12/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9465 - loss: 0.1474 - val_accuracy: 0.9152 - val_loss: 0.3733
# Epoch 13/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9722 - loss: 0.0836 - val_accuracy: 0.9196 - val_loss: 0.3751
# Epoch 14/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9702 - loss: 0.0636 - val_accuracy: 0.9174 - val_loss: 0.4300
# Epoch 15/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9744 - loss: 0.0606 - val_accuracy: 0.8951 - val_loss: 0.4034
# Epoch 16/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9793 - loss: 0.0632 - val_accuracy: 0.9152 - val_loss: 0.4978
# Epoch 17/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9748 - loss: 0.0754 - val_accuracy: 0.9018 - val_loss: 0.5322
# Epoch 18/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9814 - loss: 0.0476 - val_accuracy: 0.9174 - val_loss: 0.4410
# Epoch 19/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9866 - loss: 0.0448 - val_accuracy: 0.9129 - val_loss: 0.5673
# Epoch 20/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9861 - loss: 0.0378 - val_accuracy: 0.9174 - val_loss: 0.5482
# Epoch 21/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9881 - loss: 0.0463 - val_accuracy: 0.9174 - val_loss: 0.5385
# Epoch 22/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9806 - loss: 0.0351 - val_accuracy: 0.9107 - val_loss: 0.6125
# Epoch 23/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9900 - loss: 0.0390 - val_accuracy: 0.9174 - val_loss: 0.5701
# Epoch 24/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9797 - loss: 0.0448 - val_accuracy: 0.8996 - val_loss: 0.6674
# Epoch 25/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9882 - loss: 0.0384 - val_accuracy: 0.9152 - val_loss: 0.6168
# Epoch 26/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9917 - loss: 0.0220 - val_accuracy: 0.9129 - val_loss: 0.6780
# Epoch 27/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9884 - loss: 0.0291 - val_accuracy: 0.9129 - val_loss: 0.5814
# Epoch 28/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9940 - loss: 0.0145 - val_accuracy: 0.9174 - val_loss: 0.6756
# Epoch 29/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9960 - loss: 0.0222 - val_accuracy: 0.9174 - val_loss: 0.6214
# Epoch 30/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9808 - loss: 0.0479 - val_accuracy: 0.9219 - val_loss: 0.6640
# Epoch 31/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9899 - loss: 0.0286 - val_accuracy: 0.9219 - val_loss: 0.7366
# Epoch 32/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9911 - loss: 0.0216 - val_accuracy: 0.9241 - val_loss: 0.6338
# Epoch 33/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9945 - loss: 0.0236 - val_accuracy: 0.9129 - val_loss: 0.8719
# Epoch 34/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9918 - loss: 0.0364 - val_accuracy: 0.9018 - val_loss: 1.0787
# Epoch 35/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9853 - loss: 0.0416 - val_accuracy: 0.9018 - val_loss: 0.8383
# Epoch 36/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9905 - loss: 0.0157 - val_accuracy: 0.9152 - val_loss: 0.8876
# Epoch 37/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9913 - loss: 0.0327 - val_accuracy: 0.9196 - val_loss: 0.9469
# Epoch 38/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9928 - loss: 0.0237 - val_accuracy: 0.9241 - val_loss: 0.7854
# Epoch 39/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9842 - loss: 0.0466 - val_accuracy: 0.9196 - val_loss: 0.6620
# Epoch 40/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9934 - loss: 0.0189 - val_accuracy: 0.9196 - val_loss: 0.8261
# Epoch 41/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9931 - loss: 0.0167 - val_accuracy: 0.9196 - val_loss: 0.9551
# Epoch 42/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9894 - loss: 0.0323 - val_accuracy: 0.9219 - val_loss: 0.9197
# Epoch 43/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9928 - loss: 0.0217 - val_accuracy: 0.9107 - val_loss: 0.9286
# Epoch 44/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9912 - loss: 0.0285 - val_accuracy: 0.9196 - val_loss: 0.9432
# Epoch 45/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9864 - loss: 0.0476 - val_accuracy: 0.8951 - val_loss: 1.1131
# Epoch 46/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9919 - loss: 0.0159 - val_accuracy: 0.9219 - val_loss: 0.9187
# Epoch 47/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9955 - loss: 0.0119 - val_accuracy: 0.8929 - val_loss: 1.2456
# Epoch 48/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9882 - loss: 0.0439 - val_accuracy: 0.9040 - val_loss: 1.0573
# Epoch 49/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9914 - loss: 0.0209 - val_accuracy: 0.9174 - val_loss: 0.9776
# Epoch 50/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9942 - loss: 0.0255 - val_accuracy: 0.9129 - val_loss: 1.0025

# %% [markdown]
# This function is designed to fine-tune a pre-trained VGG16 model for a categorical image classification task, which means it's used to classify images into more than two categories.

# %%
def finetune_categorical_model():
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=(256,256,3))
    print("Model loaded.")

    #input_tensor = Input(shape=(256,256,3))
    #base_model = VGG16(weights='imagenet',include_top= False,input_tensor=input_tensor)

    top_model = Sequential()
    top_model.add(Flatten(input_shape=base_model.output_shape[1:]))
    top_model.add(Dense(256, activation='relu'))
    top_model.add(Dropout(0.5))
    top_model.add(Dense(3, activation='softmax'))

    top_model.load_weights(top_model_weights_path)

    model = Model(inputs=base_model.input, outputs=top_model(base_model.output))

    for layer in model.layers[:25]:
        layer.trainable = False

    model.compile(loss='categorical_crossentropy', optimizer=optimizers.SGD(lr=0.00001, momentum=0.9), metrics=['accuracy'])

    train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

    test_datagen = ImageDataGenerator(rescale=1./255)

    train_generator = train_datagen.flow_from_directory(train_data_dir, target_size=(img_height, img_width), batch_size=batch_size, class_mode='categorical')

    validation_generator = test_datagen.flow_from_directory(validation_data_dir, target_size=(img_height, img_width), batch_size=batch_size, class_mode='categorical')

    checkpoint = ModelCheckpoint(fine_tuned_model_path, monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto')

    fit = model.fit_generator(train_generator, steps_per_epoch=nb_train_samples//batch_size, epochs=epochs, validation_data=validation_generator, validation_steps=nb_validation_samples//batch_size, verbose=1, callbacks=[checkpoint])

    with open(location+'/ft_history.txt', 'w') as f:
        json.dump(fit.history, f)

    # Added return statement to return the model and history
    return model, fit.history

# %% [markdown]
# This Python code snippet. It defines a function called finetune_categorical_model which is designed for a specific type of machine learning task: fine-tuning a pre-trained model called VGG16 for image classification into multiple categories.

# %%
def finetune_categorical_model():
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=(256,256,3))
    print("Model loaded.")

    #input_tensor = Input(shape=(256,256,3))
    #base_model = VGG16(weights='imagenet',include_top= False,input_tensor=input_tensor)

    top_model = Sequential()
    top_model.add(Flatten(input_shape=base_model.output_shape[1:]))
    top_model.add(Dense(256, activation='relu'))
    top_model.add(Dropout(0.5))
    top_model.add(Dense(3, activation='softmax'))

    # Instead of loading weights directly, check if the file exists
    if os.path.exists(top_model_weights_path):
        try:
            top_model.load_weights(top_model_weights_path)
            print("Loaded weights from:", top_model_weights_path)
        except ValueError:
            print("Weights file incompatible. Starting with random weights.")
    else:
        print("Weights file not found. Starting with random weights.")

    model = Model(inputs=base_model.input, outputs=top_model(base_model.output))

    for layer in model.layers[:25]:
        layer.trainable = False

    model.compile(loss='categorical_crossentropy', optimizer=optimizers.SGD(lr=0.00001, momentum=0.9), metrics=['accuracy'])

# %% [markdown]
# This Python code snippet. It defines a function called finetune_categorical_model which is designed for a specific type of machine learning task: fine-tuning a pre-trained model called VGG16 for image classification into multiple categories.

# %%
def finetune_categorical_model():
    # ... (other parts of your function) ...
    model.compile(loss='categorical_crossentropy',
                  optimizer=optimizers.SGD(learning_rate=0.00001, momentum=0.9), # Changed lr to learning_rate
                  metrics=['accuracy'])

# %% [markdown]
# This function, finetune_categorical_model, is designed to adapt a pre-trained model called VGG16 to classify images into multiple categories.

# %%
def finetune_categorical_model():
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=(256,256,3))
    print("Model loaded.")

    #input_tensor = Input(shape=(256,256,3))
    #base_model = VGG16(weights='imagenet',include_top= False,input_tensor=input_tensor)

    top_model = Sequential()
    top_model.add(Flatten(input_shape=base_model.output_shape[1:]))
    top_model.add(Dense(256, activation='relu'))
    top_model.add(Dropout(0.5))
    top_model.add(Dense(3, activation='softmax'))

    # Instead of loading weights directly, check if the file exists
    if os.path.exists(top_model_weights_path):
        try:
            top_model.load_weights(top_model_weights_path)
            print("Loaded weights from:", top_model_weights_path)
        except ValueError:
            print("Weights file incompatible. Starting with random weights.")
    else:
        print("Weights file not found. Starting with random weights.")

    model = Model(inputs=base_model.input, outputs=top_model(base_model.output)) # This line defines 'model'

    for layer in model.layers[:25]:
        layer.trainable = False

    model.compile(loss='categorical_crossentropy', optimizer=optimizers.SGD(learning_rate=0.00001, momentum=0.9), metrics=['accuracy']) # Now you can compile

    # ... (rest of your finetune_categorical_model function) ...

# %% [markdown]
# This function is designed to fine-tune a pre-trained VGG16 model for image classification tasks where you have more than two categories (multi-class classification).

# %%
def finetune_categorical_model():
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=(256,256,3))
    print("Model loaded.")

    #input_tensor = Input(shape=(256,256,3))
    #base_model = VGG16(weights='imagenet',include_top= False,input_tensor=input_tensor)

    top_model = Sequential()
    top_model.add(Flatten(input_shape=base_model.output_shape[1:]))
    top_model.add(Dense(256, activation='relu'))
    top_model.add(Dropout(0.5))
    top_model.add(Dense(3, activation='softmax'))

    # Instead of loading weights directly, check if the file exists
    if os.path.exists(top_model_weights_path):
        try:
            top_model.load_weights(top_model_weights_path)
            print("Loaded weights from:", top_model_weights_path)
        except ValueError:
            print("Weights file incompatible. Starting with random weights.")
    else:
        print("Weights file not found. Starting with random weights.")

    model = Model(inputs=base_model.input, outputs=top_model(base_model.output)) # This line defines 'model'

    for layer in model.layers[:25]:
        layer.trainable = False

    model.compile(loss='categorical_crossentropy', optimizer=optimizers.SGD(learning_rate=0.00001, momentum=0.9), metrics=['accuracy']) # Now you can compile

    train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

    test_datagen = ImageDataGenerator(rescale=1./255)

    train_generator = train_datagen.flow_from_directory(train_data_dir, target_size=(img_height, img_width), batch_size=batch_size, class_mode='categorical')

    validation_generator = test_datagen.flow_from_directory(validation_data_dir, target_size=(img_height, img_width), batch_size=batch_size, class_mode='categorical')

    checkpoint = ModelCheckpoint(fine_tuned_model_path, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto') # Changed monitor to 'val_accuracy'

    fit = model.fit(train_generator, steps_per_epoch=nb_train_samples//batch_size, epochs=epochs, validation_data=validation_generator, validation_steps=nb_validation_samples//batch_size, verbose=1, callbacks=[checkpoint])

    with open(location+'/ft_history.txt', 'w') as f:
        json.dump(fit.history, f)

    # Added return statement to return the model and history
    return model, fit.history # Returning the model and history

# %% [markdown]
# This function is designed to fine-tune a pre-trained VGG16 model for image classification tasks where you have more than two categories (multi-class classification).

# %%
def finetune_categorical_model():
    # ... (other parts of your function) ...

    # Change the file extension to .keras
    fine_tuned_model_path = location + '/ft_model.keras'

    checkpoint = ModelCheckpoint(fine_tuned_model_path, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto')

    # ... (rest of your function) ...

# %% [markdown]
# This function, finetune_categorical_model, is designed to take a pre-trained model (VGG16) and adapt it to classify images into multiple categories

# %%
def finetune_categorical_model():
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=(256,256,3))
    print("Model loaded.")

    #input_tensor = Input(shape=(256,256,3))
    #base_model = VGG16(weights='imagenet',include_top= False,input_tensor=input_tensor)

    top_model = Sequential()
    top_model.add(Flatten(input_shape=base_model.output_shape[1:]))
    top_model.add(Dense(256, activation='relu'))
    top_model.add(Dropout(0.5))
    top_model.add(Dense(3, activation='softmax'))

    # Instead of loading weights directly, check if the file exists
    if os.path.exists(top_model_weights_path):
        try:
            top_model.load_weights(top_model_weights_path)
            print("Loaded weights from:", top_model_weights_path)
        except ValueError:
            print("Weights file incompatible. Starting with random weights.")
    else:
        print("Weights file not found. Starting with random weights.")

    model = Model(inputs=base_model.input, outputs=top_model(base_model.output)) # This line defines 'model'

    for layer in model.layers[:25]:
        layer.trainable = False

    model.compile(loss='categorical_crossentropy', optimizer=optimizers.SGD(learning_rate=0.00001, momentum=0.9), metrics=['accuracy']) # Now you can compile

    train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

    test_datagen = ImageDataGenerator(rescale=1./255)

    train_generator = train_datagen.flow_from_directory(train_data_dir, target_size=(img_height, img_width), batch_size=batch_size, class_mode='categorical')

    validation_generator = test_datagen.flow_from_directory(validation_data_dir, target_size=(img_height, img_width), batch_size=batch_size, class_mode='categorical')

    # Change the file extension to .keras
    fine_tuned_model_path = location + '/ft_model.keras'

    checkpoint = ModelCheckpoint(fine_tuned_model_path, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto') # Changed monitor to 'val_accuracy'

    fit = model.fit(train_generator, steps_per_epoch=nb_train_samples//batch_size, epochs=epochs, validation_data=validation_generator, validation_steps=nb_validation_samples//batch_size, verbose=1, callbacks=[checkpoint])

    with open(location+'/ft_history.txt', 'w') as f:
        json.dump(fit.history, f)

    # Added return statement to return the model and history
    return model, fit.history # Returning the model and history

# %% [markdown]
# This code snippet is part of a larger function called finetune_categorical_model. This function's purpose is to fine-tune a pre-trained model (VGG16) for image classification with more than two categories.

# %%
def finetune_categorical_model():
    # ... (other parts of your function) ...

    train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'  # Ensure class_mode is 'categorical'
    )

    validation_generator = test_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'  # Ensure class_mode is 'categorical'
    )

# %% [markdown]
# This code snippet is inside a function called finetune_categorical_model, which is designed to fine-tune a pre-trained model (VGG16) for image classification into multiple categories. This particular section focuses on preparing the image data for training and validation.

# %%
def finetune_categorical_model():
    # ... (other parts of your function) ...

    # Create the ImageDataGenerators first
    train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
    test_datagen = ImageDataGenerator(rescale=1./255)

    train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'  # Ensure class_mode is 'categorical'
    )

    validation_generator = test_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'  # Ensure class_mode is 'categorical'
    )
    # ... (rest of your function) ...

# %% [markdown]
# This code defines a function called finetune_categorical_model. This function is the core of the fine-tuning process for a pre-trained VGG16 model to classify images into multiple categories

# %%
def finetune_categorical_model():
    # ... (other parts of your function) ...

    # Ensure you are compiling the model:
    model.compile(loss='categorical_crossentropy',
                  optimizer=optimizers.SGD(learning_rate=0.00001, momentum=0.9),
                  metrics=['accuracy'])

    # ... (other parts of your function) ...

    # Ensure you are fitting the model and storing the results:
    fit = model.fit(train_generator,
                    steps_per_epoch=nb_train_samples // batch_size,
                    epochs=epochs,
                    validation_data=validation_generator,
                    validation_steps=nb_validation_samples // batch_size,
                    verbose=1,
                    callbacks=[checkpoint])

    # Ensure you are saving the history:
    with open(location + '/ft_history.txt', 'w') as f:
        json.dump(fit.history, f)

    # Make sure to return the model and history:
    return model, fit.history

# %% [markdown]
# This function, finetune_categorical_model, is designed to take a powerful, pre-trained image recognition model called VGG16 and adapt it for a new, specific image classification task with multiple categories.

# %%
def finetune_categorical_model():
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=(256,256,3))
    print("Model loaded.")

    #input_tensor = Input(shape=(256,256,3))
    #base_model = VGG16(weights='imagenet',include_top= False,input_tensor=input_tensor)

    top_model = Sequential()
    top_model.add(Flatten(input_shape=base_model.output_shape[1:]))
    top_model.add(Dense(256, activation='relu'))
    top_model.add(Dropout(0.5))
    top_model.add(Dense(3, activation='softmax'))

    # Instead of loading weights directly, check if the file exists
    if os.path.exists(top_model_weights_path):
        try:
            top_model.load_weights(top_model_weights_path)
            print("Loaded weights from:", top_model_weights_path)
        except ValueError:
            print("Weights file incompatible. Starting with random weights.")
    else:
        print("Weights file not found. Starting with random weights.")

    # Creating the 'model' by combining base_model and top_model
    model = Model(inputs=base_model.input, outputs=top_model(base_model.output))

    for layer in model.layers[:25]:
        layer.trainable = False

    # Now you can compile the model since it's been defined
    model.compile(loss='categorical_crossentropy',
                  optimizer=optimizers.SGD(learning_rate=0.00001, momentum=0.9),
                  metrics=['accuracy'])

    # ... (rest of your finetune_categorical_model function) ...

    return model, fit.history

# %% [markdown]
# This code defines a function called finetune_categorical_model. The function aims to adapt a pre-trained VGG16 model, originally trained on a massive dataset called ImageNet, to your specific image classification task.

# %%
def finetune_categorical_model():
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=(256,256,3))
    print("Model loaded.")

    #input_tensor = Input(shape=(256,256,3))
    #base_model = VGG16(weights='imagenet',include_top= False,input_tensor=input_tensor)

    top_model = Sequential()
    top_model.add(Flatten(input_shape=base_model.output_shape[1:]))
    top_model.add(Dense(256, activation='relu'))
    top_model.add(Dropout(0.5))
    top_model.add(Dense(3, activation='softmax'))

    # Instead of loading weights directly, check if the file exists
    if os.path.exists(top_model_weights_path):
        try:
            top_model.load_weights(top_model_weights_path)
            print("Loaded weights from:", top_model_weights_path)
        except ValueError:
            print("Weights file incompatible. Starting with random weights.")
    else:
        print("Weights file not found. Starting with random weights.")

    # Creating the 'model' by combining base_model and top_model
    model = Model(inputs=base_model.input, outputs=top_model(base_model.output))

    for layer in model.layers[:25]:
        layer.trainable = False

    # Now you can compile the model since it's been defined
    model.compile(loss='categorical_crossentropy',
                  optimizer=optimizers.SGD(learning_rate=0.00001, momentum=0.9),
                  metrics=['accuracy'])

    # Create the ImageDataGenerators first
    train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
    test_datagen = ImageDataGenerator(rescale=1./255)

    train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'  # Ensure class_mode is 'categorical'
    )

    validation_generator = test_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'  # Ensure class_mode is 'categorical'
    )

    # Change the file extension to .keras
    fine_tuned_model_path = location + '/ft_model.keras'

    checkpoint = ModelCheckpoint(fine_tuned_model_path, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto') # Changed monitor to 'val_accuracy'

    # This line is added to fit the model and assign it to 'fit'
    fit = model.fit(train_generator, steps_per_epoch=nb_train_samples//batch_size, epochs=epochs, validation_data=validation_generator, validation_steps=nb_validation_samples//batch_size, verbose=1, callbacks=[checkpoint])

    with open(location+'/ft_history.txt', 'w') as f:
        json.dump(fit.history, f)

    # Added return statement to return the model and history
    return model, fit.history # Returning the model and history

# %% [markdown]
#  It defines a function called finetune_categorical_model, which is designed to adapt a pre-trained image recognition model (VGG16) for a specific image classification task with multiple categories.

# %%
def finetune_categorical_model():
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=(256,256,3))
    print("Model loaded.")

    #input_tensor = Input(shape=(256,256,3))
    #base_model = VGG16(weights='imagenet',include_top= False,input_tensor=input_tensor)

    top_model = Sequential()
    top_model.add(Flatten(input_shape=base_model.output_shape[1:]))
    top_model.add(Dense(256, activation='relu'))
    top_model.add(Dropout(0.5))

    # Change the number of neurons in the output layer to match the number of classes
    num_classes = len(os.listdir(train_data_dir))  # Get the number of classes from the training directory
    top_model.add(Dense(num_classes, activation='softmax'))

    # Instead of loading weights directly, check if the file exists
    if os.path.exists(top_model_weights_path):
        try:
            top_model.load_weights(top_model_weights_path)
            print("Loaded weights from:", top_model_weights_path)
        except ValueError:
            print("Weights file incompatible. Starting with random weights.")
    else:
        print("Weights file not found. Starting with random weights.")

    # Creating the 'model' by combining base_model and top_model
    model = Model(inputs=base_model.input, outputs=top_model(base_model.output))

    for layer in model.layers[:25]:
        layer.trainable = False

    # Now you can compile the model since it's been defined
    model.compile(loss='categorical_crossentropy',
                  optimizer=optimizers.SGD(learning_rate=0.00001, momentum=0.9),
                  metrics=['accuracy'])

    # Create the ImageDataGenerators first
    train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
    test_dat

# %% [markdown]
# This code defines a function called finetune_categorical_model. Its purpose is to take a pre-trained VGG16 model and adapt it to classify images into multiple categories

# %%
def finetune_categorical_model():
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=(256,256,3))
    print("Model loaded.")

    #input_tensor = Input(shape=(256,256,3))
    #base_model = VGG16(weights='imagenet',include_top= False,input_tensor=input_tensor)

    top_model = Sequential()
    top_model.add(Flatten(input_shape=base_model.output_shape[1:]))
    top_model.add(Dense(256, activation='relu'))
    top_model.add(Dropout(0.5))

    # Change the number of neurons in the output layer to match the number of classes
    num_classes = len(os.listdir(train_data_dir))  # Get the number of classes from the training directory
    top_model.add(Dense(num_classes, activation='softmax'))

    # Instead of loading weights directly, check if the file exists
    if os.path.exists(top_model_weights_path):
        try:
            top_model.load_weights(top_model_weights_path)
            print("Loaded weights from:", top_model_weights_path)
        except ValueError:
            print("Weights file incompatible. Starting with random weights.")
    else:
        print("Weights file not found. Starting with random weights.")

    # Creating the 'model' by combining base_model and top_model
    model = Model(inputs=base_model.input, outputs=top_model(base_model.output))

    for layer in model.layers[:25]:
        layer.trainable = False

    # Now you can compile the model since it's been defined
    model.compile(loss='categorical_crossentropy',
                  optimizer=optimizers.SGD(learning_rate=0.00001, momentum=0.9),
                  metrics=['accuracy'])

    # Create the ImageDataGenerators first
    train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
    test_datagen = ImageDataGenerator(rescale=1./255) # This line was incomplete and caused the error

    train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'  # Ensure class_mode is 'categorical'
    )

    validation_generator = test_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'  # Ensure class_mode is 'categorical'
    )

    # Change the file extension to .keras
    fine_tuned_model_path = location + '/ft_model.keras'

    checkpoint = ModelCheckpoint(fine_tuned_model_path, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto') # Changed monitor to 'val_accuracy'

    fit = model.fit(train_generator, steps_per_epoch=nb_train_samples//batch_size, epochs=epochs, validation_data=validation_generator, validation_steps=nb_validation_samples//batch_size, verbose=1, callbacks=[checkpoint])

    with open(location+'/ft_history.txt', 'w') as f:
        json.dump(fit.history, f)

    # Added return statement to return the model and history
    return model, fit.history # Returning the model and history

# %% [markdown]
# This line is like starting a machine (the function) that processes your images and produces two outputs: a fine-tuned model (ft_model) and a report of how the training went (ft_history). You then store these outputs for later use.

# %%
ft_model, ft_history = finetune_categorical_model()
# Out:
# Model loaded.
# Weights file not found. Starting with random weights.
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py:75: UserWarning: The model does not have any trainable weights.
#   warnings.warn("The model does not have any trainable weights.")
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.4939 - loss: 0.9410
# Epoch 1: val_accuracy improved from -inf to 0.47321, saving model to /content/drive/MyDrive/data2/ft_model.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 50s 386ms/step - accuracy: 0.4938 - loss: 0.9410 - val_accuracy: 0.4732 - val_loss: 0.8671
# Epoch 2/50
#   1/114 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.5625 - loss: 0.7593
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# Epoch 2: val_accuracy improved from 0.47321 to 0.50000, saving model to /content/drive/MyDrive/data2/ft_model.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 11s 98ms/step - accuracy: 0.5625 - loss: 0.7593 - val_accuracy: 0.5000 - val_loss: 0.8689
# Epoch 3/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.4756 - loss: 0.9935
# Epoch 3: val_accuracy did not improve from 0.50000
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 45s 374ms/step - accuracy: 0.4757 - loss: 0.9932 - val_accuracy: 0.4710 - val_loss: 0.8688
# Epoch 4/50
#   1/114 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - accuracy: 0.5000 - loss: 0.9559
# Epoch 4: val_accuracy improved from 0.50000 to 0.58333, saving model to /content/drive/MyDrive/data2/ft_model.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5000 - loss: 0.9559 - val_accuracy: 0.5833 - val_loss: 0.8038
# Epoch 5/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.4839 - loss: 0.9657
# Epoch 5: val_accuracy did not improve from 0.58333
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 81s 377ms/step - accuracy: 0.4838 - loss: 0.9659 - val_accuracy: 0.4754 - val_loss: 0.8665
# Epoch 6/50
#   1/114 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.3750 - loss: 1.1976
# Epoch 6: val_accuracy did not improve from 0.58333
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.3750 - loss: 1.1976 - val_accuracy: 0.4167 - val_loss: 0.8907
# Epoch 7/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.4832 - loss: 0.9785
# Epoch 7: val_accuracy did not improve from 0.58333
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 82s 392ms/step - accuracy: 0.4833 - loss: 0.9783 - val_accuracy: 0.4688 - val_loss: 0.8727
# Epoch 8/50
#   1/114 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - accuracy: 0.3750 - loss: 1.0998
# Epoch 8: val_accuracy improved from 0.58333 to 0.66667, saving model to /content/drive/MyDrive/data2/ft_model.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3750 - loss: 1.0998 - val_accuracy: 0.6667 - val_loss: 0.6563
# Epoch 9/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.4765 - loss: 0.9829
# Epoch 9: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 84s 423ms/step - accuracy: 0.4766 - loss: 0.9828 - val_accuracy: 0.4688 - val_loss: 0.8706
# Epoch 10/50
#   1/114 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.5000 - loss: 1.0940
# Epoch 10: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.5000 - loss: 1.0940 - val_accuracy: 0.6667 - val_loss: 0.7356
# Epoch 11/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.4686 - loss: 0.9656
# Epoch 11: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 80s 406ms/step - accuracy: 0.4687 - loss: 0.9655 - val_accuracy: 0.4710 - val_loss: 0.8720
# Epoch 12/50
#   1/114 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.5000 - loss: 1.2347
# Epoch 12: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.5000 - loss: 1.2347 - val_accuracy: 0.5833 - val_loss: 0.6854
# Epoch 13/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - accuracy: 0.4950 - loss: 0.9473
# Epoch 13: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 84s 440ms/step - accuracy: 0.4949 - loss: 0.9473 - val_accuracy: 0.4754 - val_loss: 0.8662
# Epoch 14/50
#   1/114 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - accuracy: 0.6875 - loss: 0.6156
# Epoch 14: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - accuracy: 0.6875 - loss: 0.6156 - val_accuracy: 0.4167 - val_loss: 0.8996
# Epoch 15/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.4792 - loss: 0.9828
# Epoch 15: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 81s 434ms/step - accuracy: 0.4793 - loss: 0.9826 - val_accuracy: 0.4732 - val_loss: 0.8694
# Epoch 16/50
#   1/114 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - accuracy: 0.3125 - loss: 1.3691
# Epoch 16: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - accuracy: 0.3125 - loss: 1.3691 - val_accuracy: 0.5000 - val_loss: 0.7831
# Epoch 17/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.4700 - loss: 0.9547
# Epoch 17: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 46s 386ms/step - accuracy: 0.4700 - loss: 0.9549 - val_accuracy: 0.4732 - val_loss: 0.8653
# Epoch 18/50
#   1/114 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - accuracy: 0.5000 - loss: 0.9606
# Epoch 18: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - accuracy: 0.5000 - loss: 0.9606 - val_accuracy: 0.5000 - val_loss: 0.9333
# Epoch 19/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.4779 - loss: 0.9737
# Epoch 19: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 49s 413ms/step - accuracy: 0.4778 - loss: 0.9738 - val_accuracy: 0.4710 - val_loss: 0.8718
# Epoch 20/50
#   1/114 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.2500 - loss: 1.0519
# Epoch 20: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - accuracy: 0.2500 - loss: 1.0519 - val_accuracy: 0.5833 - val_loss: 0.6926
# Epoch 21/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.4748 - loss: 0.9570
# Epoch 21: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 81s 403ms/step - accuracy: 0.4748 - loss: 0.9570 - val_accuracy: 0.4754 - val_loss: 0.8696
# Epoch 22/50
#   1/114 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.3125 - loss: 1.0432
# Epoch 22: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.3125 - loss: 1.0432 - val_accuracy: 0.4167 - val_loss: 0.7721
# Epoch 23/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.5083 - loss: 0.9165
# Epoch 23: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 49s 408ms/step - accuracy: 0.5081 - loss: 0.9168 - val_accuracy: 0.4799 - val_loss: 0.8596
# Epoch 24/50
#   1/114 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.4375 - loss: 1.1524
# Epoch 24: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - accuracy: 0.4375 - loss: 1.1524 - val_accuracy: 0.2500 - val_loss: 1.1477
# Epoch 25/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.4748 - loss: 0.9415
# Epoch 25: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 50s 414ms/step - accuracy: 0.4748 - loss: 0.9416 - val_accuracy: 0.4688 - val_loss: 0.8720
# Epoch 26/50
#   1/114 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.6875 - loss: 0.6233
# Epoch 26: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - accuracy: 0.6875 - loss: 0.6233 - val_accuracy: 0.6667 - val_loss: 0.6830
# Epoch 27/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.4749 - loss: 0.9644
# Epoch 27: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 78s 379ms/step - accuracy: 0.4751 - loss: 0.9643 - val_accuracy: 0.4710 - val_loss: 0.8673
# Epoch 28/50
#   1/114 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.5000 - loss: 1.0055
# Epoch 28: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - accuracy: 0.5000 - loss: 1.0055 - val_accuracy: 0.5833 - val_loss: 0.8601
# Epoch 29/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.5032 - loss: 0.9401
# Epoch 29: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 46s 376ms/step - accuracy: 0.5031 - loss: 0.9403 - val_accuracy: 0.4777 - val_loss: 0.8656
# Epoch 30/50
#   1/114 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.3125 - loss: 1.2348
# Epoch 30: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step - accuracy: 0.3125 - loss: 1.2348 - val_accuracy: 0.3333 - val_loss: 0.9227
# Epoch 31/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.4829 - loss: 0.9454
# Epoch 31: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 81s 379ms/step - accuracy: 0.4829 - loss: 0.9455 - val_accuracy: 0.4777 - val_loss: 0.8610
# Epoch 32/50
#   1/114 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.6250 - loss: 0.6677
# Epoch 32: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - accuracy: 0.6250 - loss: 0.6677 - val_accuracy: 0.3333 - val_loss: 1.0936
# Epoch 33/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.4705 - loss: 0.9751
# Epoch 33: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 82s 378ms/step - accuracy: 0.4705 - loss: 0.9749 - val_accuracy: 0.4688 - val_loss: 0.8727
# Epoch 34/50
#   1/114 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.2500 - loss: 1.4923
# Epoch 34: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - accuracy: 0.2500 - loss: 1.4923 - val_accuracy: 0.6667 - val_loss: 0.6580
# Epoch 35/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.4875 - loss: 0.9534
# Epoch 35: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 45s 376ms/step - accuracy: 0.4875 - loss: 0.9535 - val_accuracy: 0.4754 - val_loss: 0.8648
# Epoch 36/50
#   1/114 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.4375 - loss: 1.0998
# Epoch 36: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.4375 - loss: 1.0998 - val_accuracy: 0.4167 - val_loss: 0.9520
# Epoch 37/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.4787 - loss: 0.9736
# Epoch 37: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 80s 375ms/step - accuracy: 0.4788 - loss: 0.9735 - val_accuracy: 0.4710 - val_loss: 0.8711
# Epoch 38/50
#   1/114 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.4375 - loss: 1.0070
# Epoch 38: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.4375 - loss: 1.0070 - val_accuracy: 0.5833 - val_loss: 0.7184
# Epoch 39/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.4893 - loss: 0.9319
# Epoch 39: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 45s 375ms/step - accuracy: 0.4894 - loss: 0.9320 - val_accuracy: 0.4732 - val_loss: 0.8697
# Epoch 40/50
#   1/114 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - accuracy: 0.6250 - loss: 0.7574
# Epoch 40: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - accuracy: 0.6250 - loss: 0.7574 - val_accuracy: 0.5000 - val_loss: 0.7683
# Epoch 41/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.4895 - loss: 0.9597
# Epoch 41: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 45s 377ms/step - accuracy: 0.4895 - loss: 0.9597 - val_accuracy: 0.4688 - val_loss: 0.8727
# Epoch 42/50
#   1/114 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.5625 - loss: 0.8953
# Epoch 42: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - accuracy: 0.5625 - loss: 0.8953 - val_accuracy: 0.6667 - val_loss: 0.6580
# Epoch 43/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.4633 - loss: 0.9613
# Epoch 43: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 45s 377ms/step - accuracy: 0.4633 - loss: 0.9612 - val_accuracy: 0.4710 - val_loss: 0.8697
# Epoch 44/50
#   1/114 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.5000 - loss: 0.8505
# Epoch 44: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.5000 - loss: 0.8505 - val_accuracy: 0.5833 - val_loss: 0.7710
# Epoch 45/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.4891 - loss: 0.9610
# Epoch 45: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 45s 377ms/step - accuracy: 0.4892 - loss: 0.9609 - val_accuracy: 0.4754 - val_loss: 0.8698
# Epoch 46/50
#   1/114 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.5625 - loss: 0.7996
# Epoch 46: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - accuracy: 0.5625 - loss: 0.7996 - val_accuracy: 0.4167 - val_loss: 0.7667
# Epoch 47/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.5112 - loss: 0.9020
# Epoch 47: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 45s 380ms/step - accuracy: 0.5110 - loss: 0.9023 - val_accuracy: 0.4777 - val_loss: 0.8656
# Epoch 48/50
#   1/114 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.4375 - loss: 1.0544
# Epoch 48: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - accuracy: 0.4375 - loss: 1.0544 - val_accuracy: 0.3333 - val_loss: 0.9243
# Epoch 49/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.5194 - loss: 0.9293
# Epoch 49: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 81s 373ms/step - accuracy: 0.5193 - loss: 0.9295 - val_accuracy: 0.4754 - val_loss: 0.8701
# Epoch 50/50
#   1/114 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - accuracy: 0.6250 - loss: 0.7955
# Epoch 50: val_accuracy did not improve from 0.66667
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - accuracy: 0.6250 - loss: 0.7955 - val_accuracy: 0.4167 - val_loss: 0.7547

# %% [markdown]
# This function is designed to identify and display the best performing epoch (training cycle) of your machine learning model.

# %%
def print_best_model_results(model_hist):
    best_epoch = np.argmax(model_hist['val_accuracy']) # Changed 'val_acc' to 'val_accuracy'
    print('epoch:', best_epoch+1, \
          ', val_acc:', model_hist['val_accuracy'][best_epoch], \
          ', val_loss:', model_hist['val_loss'][best_epoch])

def plot_metrics(hist, stop=50):
    # ... (other parts of the function remain the same)

    axes[0].plot(range(stop), hist['accuracy'], label='Training', color='#FF533D')
    axes[0].plot(range(stop), hist['val_accuracy'], label='Validation', color='#03507E') # Changed 'val_acc' to 'val_accuracy'

    # ... (rest of the function remains the same)

# %% [markdown]
#  It's defining a function called plot_metrics which is used to visualize the performance of a machine learning model during training.

# %%
def plot_metrics(hist, stop=50):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,4))

    # Assign the flattened array to a new variable, e.g., 'ax'
    ax = axes.flatten()

    # Use 'ax' to access the individual subplots
    ax[0].plot(range(stop), hist['accuracy'], label='Training', color='#FF533D')
    ax[0].plot(range(stop), hist['val_accuracy'], label='Validation', color='#03507E')
    ax[0].set_title('Accuracy')
    ax[0].set_ylabel('Accuracy')
    ax[0].set_xlabel('Epoch')
    ax[0].legend(loc='lower right')

    ax[1].plot(range(stop), hist['loss'], label='Training', color='#FF533D')
    ax[1].plot(range(stop), hist['val_loss'], label='Validation', color='#03507E')
    ax[1].set_title('Loss')
    ax[1].set_ylabel('Loss')
    ax[1].set_xlabel('Epoch')
    ax[1].legend(loc='upper right')

    plt.tight_layout();

    print("Best Model:")
    print_best_model_results(hist)

# %% [markdown]
# Accuracy Plot: Shows how the accuracy of your model changed during fine-tuning, both on the training data and validation data.
#
# Loss Plot: Shows how the loss (error) of your model changed during fine-tuning, again for both training and validation data.

# %%
plot_metrics(ft_history)
# Out:
# Best Model:
# epoch: 8 , val_acc: 0.6666666865348816 , val_loss: 0.6563326120376587

# %% [markdown]
# # Load Model

# %% [markdown]
# This line is responsible for loading a previously saved, trained model back into your Python environment so you can use it for making predictions or further analysis

# %%
ft_model = load_model(location+'/ft_model.keras') # Change the file extension to .keras

# %% [markdown]
# This code is designed to load the training history of a previously trained machine learning model. This history contains information about the model's performance (accuracy, loss, etc.) during its training process.

# %%
# Change 'data1a/top_history.txt' to the correct file path.
# Here, we assume that the file is in the 'location' directory.
with open(location + '/top_history.txt') as f:
    top_history = json.load(f)

# %% [markdown]
# This code is designed to load the training history of a previously trained machine learning model, specifically the fine-tuning stage, and store it in a variable called ft_history. This history contains valuable information about the model's performance during the training process, which can be used for analysis and visualization.

# %%
with open(location + '/ft_history.txt') as f:
    ft_history = json.load(f)

# %% [markdown]
# This code defines a function called plot_acc_metrics. Its primary purpose is to create a plot that visually compares the accuracy of a machine learning model during two phases: initial training (hist1) and fine-tuning (hist2). This comparison helps you understand how the model's performance improves after fine-tuning

# %%
def plot_acc_metrics(hist1, hist2, stop=50):
    fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(4.25,6))

    axes = axes.flatten()

    # Access 'accuracy' and 'val_accuracy' instead of 'acc' and 'val_acc'
    axes[0].plot(range(stop), hist1['accuracy'], label='Training', color='#FF533D')
    axes[0].plot(range(stop), hist1['val_accuracy'], label='Validation', color='#03507E')
    axes[0].set_title('Training')
    axes[0].set_ylabel('Accuracy')
    axes[0].set_xlabel('Epoch')
    axes[0].legend(loc='lower right')

    axes[1].plot(range(stop), hist2['accuracy'], label='Training', color='#FF533D')
    axes[1].plot(range(stop), hist2['val_accuracy'], label='Validation', color='#03507E')
    axes[1].set_title('Fine-tuning')
    axes[1].set_ylabel('Accuracy')
    axes[1].set_xlabel('Epoch')
    axes[1].legend(loc='lower right')

    plt.tight_layout();

# %% [markdown]
# This line of code triggers the creation of a plot that visually compares the accuracy of the model before and after the fine-tuning process, using the training history data stored in the top_history and ft_history variables.

# %%
plot_acc_metrics(top_history, ft_history)

# %% [markdown]
# This line is creating an array called validation_labels which is used to store the true labels for your validation dataset. This is crucial for evaluating how well your model is performing.

# %%
validation_labels = np.array([0] * (nb_validation_samples // 2) + [1] * (nb_validation_samples // 2))

# %% [markdown]
# This function, evaluate_binary_model, is designed to assess the performance of a trained binary classification model, likely used for image classification.

# %%
def evaluate_binary_model(model, directory, labels):
    datagen = ImageDataGenerator(rescale=1./255)

    generator = datagen.flow_from_directory(directory, target_size=(img_height,img_width), batch_size=batch_size, class_mode='binary', shuffle=False)

    # Replace predict_generator with predict and adjust arguments
    predictions = model.predict(generator, steps=len(labels) // batch_size)

    pred_labels = [0 if i<0.5 else 1 for i in predictions]

    print('')
    print(classification_report(validation_labels, pred_labels))
    print('')
    cm = confusion_matrix(validation_labels, pred_labels)
    return cm

# %% [markdown]
# This function, evaluate_binary_model, is designed to evaluate the performance of a trained binary classification model on a set of images.

# %%
def evaluate_binary_model(model, directory, labels):
    datagen = ImageDataGenerator(rescale=1./255)

    generator = datagen.flow_from_directory(directory, target_size=(img_height,img_width), batch_size=batch_size, class_mode='binary', shuffle=False)

    # Replace predict_generator with predict and adjust arguments
    predictions = model.predict(generator, steps=len(labels) // batch_size)

    # Compare the first element of the prediction to 0.5
    pred_labels = [0 if i[0] < 0.5 else 1 for i in predictions]

    print('')
    print(classification_report(validation_labels, pred_labels))
    print('')
    cm = confusion_matrix(validation_labels, pred_labels)
    return cm

# %% [markdown]
# This line is the culmination of the model evaluation process. It's calling the evaluate_binary_model function to assess the performance of your fine-tuned model (ft_model) and storing the results in a variable called cm.

# %%
cm = evaluate_binary_model(ft_model, validation_data_dir, validation_labels)
# Out:
# Found 460 images belonging to 2 classes.
#  2/28 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step
#
#               precision    recall  f1-score   support
#
#            0       0.51      0.98      0.67       224
#            1       0.77      0.08      0.14       224
#
#     accuracy                           0.53       448
#    macro avg       0.64      0.53      0.41       448
# weighted avg       0.64      0.53      0.41       448

# %% [markdown]
# Imagine you have a heatmap that shows the performance of your image classification model. This line of code is basically defining the labels you want to use for the rows or columns of that heatmap. In this case, those labels are 'Damaged' and 'Whole', which might correspond to the two classes your model is trying to distinguish between (e.g., classifying images of objects as either damaged or whole).

# %%
heatmap_laebls = ['Damaged', 'Whole']

# %% [markdown]
# These two lines of code work together to generate a heatmap visualization of a confusion matrix (likely representing the results of an image classification model). The heatmap will have 'Damaged' and 'Whole' as labels for its rows and columns, visually showing how the model performed in classifying images into these categories using colored cells and numerical annotations. It uses an orange-to-red color scheme for visual clarity

# %%
heatmap_labels = ['Damaged', 'Whole']  # Corrected spelling
sns.heatmap(cm, annot=True, annot_kws={"size":16}, fmt='g', cmap='OrRd', xticklabels=heatmap_labels, yticklabels=heatmap_labels)
# Out:
# <Axes: >

# %% [markdown]
# This line is using the Seaborn library (sns) to create a heatmap visualization of a confusion matrix, which is stored in the variable cm. A confusion matrix is a table that is often used to describe the performance of a classification model.

# %%
sns.heatmap(cm, annot=True, annot_kws={"size": 16}, fmt='g', cmap='Blues', xticklabels=heatmap_labels, yticklabels=heatmap_labels)
# Out:
# <Axes: >

# %% [markdown]
# # Path2

# %% [markdown]
#  The path2 function takes an image, pre-processes it, uses a trained model to predict if there is damage, and provides feedback to the user based on the prediction.

# %%
def path2(image_path, model):
    urllib.request.urlretrieve(image_path, 'save.jpg')
    img = load_img('save.jpg', target_size=(256,256))
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)/255
    pred = model.predict(x)
    print("Validating that damage exists....")
    print(pred)
    if(pred[0][0]<=0.5):
        print("Validation complete - proceed to location and severity determination")
    else:
        print ("Are you sure that your car is damaged? Please submit another picture of the damage.")
        print ("Hint: Try zooming in/out, using a different angle or different lighting")

# %% [markdown]
# This line is using the Image function (likely from the IPython.display module, which was imported earlier in the notebook) to display an image within the Jupyter notebook.

# %%
Image('http://3.bp.blogspot.com/-PrRY9XxCqYQ/UDNutnMI7LI/AAAAAAAABdw/UGygghh-hRA/s1600/Bumper+scuff.JPG')

# %% [markdown]
# This line is essentially making a prediction on an image using the path2 function and the fine-tuned model ft_model.

# %%
path2('http://3.bp.blogspot.com/-PrRY9XxCqYQ/UDNutnMI7LI/AAAAAAAABdw/UGygghh-hRA/s1600/Bumper+scuff.JPG', ft_model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Validating that damage exists....
# [[0.43607798 0.56392205]]
# Validation complete - proceed to location and severity determination

# %% [markdown]
# This line of code is designed to display an image directly within your Jupyter Notebook.

# %%
Image('https://i.ytimg.com/vi/4oV1klVPogY/maxresdefault.jpg')

# %% [markdown]
# This line is using the path2 function to make a prediction on an image.

# %%
path2('https://i.ytimg.com/vi/4oV1klVPogY/maxresdefault.jpg', ft_model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Validating that damage exists....
# [[0.15272956 0.8472705 ]]
# Validation complete - proceed to location and severity determination

# %%
Image('/content/1.jpg.jpg')

# %%
def path2(image_path, model):
    # Use load_img directly for local files
    img = load_img(image_path, target_size=(256,256))
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)/255
    # ... (rest of your path2 function) ...

# %%
path2('/content/1.jpg.jpg', ft_model)
